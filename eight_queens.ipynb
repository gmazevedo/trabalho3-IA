# %%
from eight_queens import *

individuals, inf_graph = run_ga(69, 60, 5, 0.6263436754373918, True, True)
best = evaluate(individuals)
print(best, individuals)
# Out:
# 0 [6, 2, 7, 1, 3, 5, 8, 4]

# %%
import numpy as np
import matplotlib.pyplot as plt

max_fit = inf_graph[0]
min_fit = inf_graph[1]
avarage_fit = inf_graph[2]
n_range = inf_graph[3]
x = np.arange(0, n_range)

plt.figure(figsize=(6, 4))
plt.plot(x, min_fit, color='green', label='Menor') 
plt.plot(x, max_fit, color='red', label='Maior')
plt.plot(x, avarage_fit, color='blue', label='Media')

plt.xlabel("Gerações",fontsize=13)
plt.ylabel("Fitness",fontsize=13)

plt.legend()
plt.show()
plt.close()
